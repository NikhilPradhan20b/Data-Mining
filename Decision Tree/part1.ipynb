# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("Dataset.csv")

# %%
dataset.head()
# Out:
#     Outlook Temperature Humidity  Windy Play
# 0     sunny         hot     high  False   No
# 1     sunny         hot     high   True   No
# 2  overcast         hot     high  False  Yes
# 3     rainy        mild     high  False  Yes
# 4     rainy        cool   normal  False  Yes

# %%
target = dataset['Play']
target.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# Name: Play, dtype: object

# %%
dataset = dataset.drop("Play",axis=1)

# %%
dataset = pd.get_dummies(dataset)
dataset
# Out:
#     Windy  Outlook_overcast  Outlook_rainy  Outlook_sunny  Temperature_cool  \
# 0   False             False          False           True             False
# 1    True             False          False           True             False
# 2   False              True          False          False             False
# 3   False             False           True          False             False
# 4   False             False           True          False              True
# 5    True             False           True          False              True
# 6    True              True          False          False              True
# 7   False             False          False           True             False
# 8   False             False          False           True              True
# 9   False             False           True          False             False
# 10   True             False          False           True             False
# 11   True              True          False          False             False
# 12  False              True          False          False             False
# 13   True             False           True          False             False
#
#     Temperature_hot  Temperature_mild  Humidity_high  Humidity_normal
# 0              True             False           True            False
# 1              True             False           True            False
# 2              True             False           True            False
# 3             False              True           True            False
# 4             False             False          False             True
# 5             False             False          False             True
# 6             False             False          False             True
# 7             False              True           True            False
# 8             False             False          False             True
# 9             False              True          False             True
# 10            False              True          False             True
# 11            False              True           True            False
# 12             True             False          False             True
# 13            False              True           True            False

# %%
dataset = pd.concat([dataset,target],axis=1)
dataset
# Out:
#     Windy  Outlook_overcast  Outlook_rainy  Outlook_sunny  Temperature_cool  \
# 0   False             False          False           True             False
# 1    True             False          False           True             False
# 2   False              True          False          False             False
# 3   False             False           True          False             False
# 4   False             False           True          False              True
# 5    True             False           True          False              True
# 6    True              True          False          False              True
# 7   False             False          False           True             False
# 8   False             False          False           True              True
# 9   False             False           True          False             False
# 10   True             False          False           True             False
# 11   True              True          False          False             False
# 12  False              True          False          False             False
# 13   True             False           True          False             False
#
#     Temperature_hot  Temperature_mild  Humidity_high  Humidity_normal Play
# 0              True             False           True            False   No
# 1              True             False           True            False   No
# 2              True             False           True            False  Yes
# 3             False              True           True            False  Yes
# 4             False             False          False             True  Yes
# 5             False             False          False             True   No
# 6             False             False          False             True  Yes
# 7             False              True           True            False   No
# 8             False             False          False             True  Yes
# 9             False              True          False             True  Yes
# 10            False              True          False             True  Yes
# 11            False              True           True            False  Yes
# 12             True             False          False             True  Yes
# 13            False              True           True            False   No

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier = DecisionTreeClassifier(criterion='entropy',random_state=40)

# %%
X = dataset.iloc[:,:9]

# %%
X
# Out:
#     Windy  Outlook_overcast  Outlook_rainy  Outlook_sunny  Temperature_cool  \
# 0   False             False          False           True             False
# 1    True             False          False           True             False
# 2   False              True          False          False             False
# 3   False             False           True          False             False
# 4   False             False           True          False              True
# 5    True             False           True          False              True
# 6    True              True          False          False              True
# 7   False             False          False           True             False
# 8   False             False          False           True              True
# 9   False             False           True          False             False
# 10   True             False          False           True             False
# 11   True              True          False          False             False
# 12  False              True          False          False             False
# 13   True             False           True          False             False
#
#     Temperature_hot  Temperature_mild  Humidity_high  Humidity_normal
# 0              True             False           True            False
# 1              True             False           True            False
# 2              True             False           True            False
# 3             False              True           True            False
# 4             False             False          False             True
# 5             False             False          False             True
# 6             False             False          False             True
# 7             False              True           True            False
# 8             False             False          False             True
# 9             False              True          False             True
# 10            False              True          False             True
# 11            False              True           True            False
# 12             True             False          False             True
# 13            False              True           True            False

# %%
Y = dataset.iloc[:,9]

# %%
Y
# Out:
# 0      No
# 1      No
# 2     Yes
# 3     Yes
# 4     Yes
# 5      No
# 6     Yes
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13     No
# Name: Play, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.77)

# %%
X_train
# Out:
#     Windy  Outlook_overcast  Outlook_rainy  Outlook_sunny  Temperature_cool  \
# 0   False             False          False           True             False
# 7   False             False          False           True             False
# 10   True             False          False           True             False
# 1    True             False          False           True             False
# 9   False             False           True          False             False
# 12  False              True          False          False             False
# 8   False             False          False           True              True
# 3   False             False           True          False             False
# 13   True             False           True          False             False
# 5    True             False           True          False              True
#
#     Temperature_hot  Temperature_mild  Humidity_high  Humidity_normal
# 0              True             False           True            False
# 7             False              True           True            False
# 10            False              True          False             True
# 1              True             False           True            False
# 9             False              True          False             True
# 12             True             False          False             True
# 8             False             False          False             True
# 3             False              True           True            False
# 13            False              True           True            False
# 5             False             False          False             True

# %%
Y_train
# Out:
# 0      No
# 7      No
# 10    Yes
# 1      No
# 9     Yes
# 12    Yes
# 8     Yes
# 3     Yes
# 13     No
# 5      No
# Name: Play, dtype: object

# %%
Train = pd.concat([X_train,Y_train],axis=1)

# %%
Train
# Out:
#     Windy  Outlook_overcast  Outlook_rainy  Outlook_sunny  Temperature_cool  \
# 0   False             False          False           True             False
# 7   False             False          False           True             False
# 10   True             False          False           True             False
# 1    True             False          False           True             False
# 9   False             False           True          False             False
# 12  False              True          False          False             False
# 8   False             False          False           True              True
# 3   False             False           True          False             False
# 13   True             False           True          False             False
# 5    True             False           True          False              True
#
#     Temperature_hot  Temperature_mild  Humidity_high  Humidity_normal Play
# 0              True             False           True            False   No
# 7             False              True           True            False   No
# 10            False              True          False             True  Yes
# 1              True             False           True            False   No
# 9             False              True          False             True  Yes
# 12             True             False          False             True  Yes
# 8             False             False          False             True  Yes
# 3             False              True           True            False  Yes
# 13            False              True           True            False   No
# 5             False             False          False             True   No

# %%
model = classifier.fit(X_train,Y_train)

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array(['Yes', 'No', 'Yes', 'No'], dtype=object)

# %%
Y_test
# Out:
# 2     Yes
# 11    Yes
# 6     Yes
# 4     Yes
# Name: Play, dtype: object
